# %%
print("Hola \n En este informe podrás conocer acerca de el movimiento parabólico, a su vez al final encontrar una cálculadora de ecuaciones de movimiento semiparabólico \n")
print("Comencemos con conceptos clave \n")
print(" El tiro parabólico se da en consecuencia de la composición de un movimiento rectilíneo uniforme (mru horizontal) \n y un movimiento rectilíneo uniformemente acelerado de lanzamiento hacia arriba o hacia abajo (mrua vertical) [1].\n El desplazamiento de un cuerpo en dicho movimiento corresponde a la trayectoria de unaparábola, \n esto ocurre debido a dos suposiciones: el medio en el que ocurre el lanzamiento es un medio ideal \n (se desprecia la resistencia al aire) y la aceleración de caída libre es constante en el intervalo de movimiento y su dirección es hacia abajo \n")
# Out:
# Hola
#  En este informe podrás conocer acerca de el movimiento parabólico, a su vez al final encontrar una cálculadora de ecuaciones de movimiento semiparabólico
#
# Comencemos con conceptos clave
#
#  El tiro parabólico se da en consecuencia de la composición de un movimiento rectilíneo uniforme (mru horizontal)
#  y un movimiento rectilíneo uniformemente acelerado de lanzamiento hacia arriba o hacia abajo (mrua vertical) [1].
#  El desplazamiento de un cuerpo en dicho movimiento corresponde a la trayectoria de unaparábola,
#  esto ocurre debido a dos suposiciones: el medio en el que ocurre el lanzamiento es un medio ideal
#  (se desprecia la resistencia al aire) y la aceleración de caída libre es constante en el intervalo de movimiento y su dirección es hacia abajo

# %% [markdown]
# ![parabólico.PNG](data:image/png;base64,...)

# %%
print("En esa imagen puedes evidenciar el montaje utilizado \n"  )
print("En el montaje el objeto que experimentó el movimiento parabólico fue un balín de metal, \n experimentó dicho movimiento en varias ocasiones, entre cada una, se realizaron cambios en su \n ángulo, estos permitieron tener una variedad de datos y analizarlos, al caer el balín sobre la mesa\n se efectuaron mediciones gracias a la marca que este generó en el papel carbón. ")
# Out:
# En esa imagen puedes evidenciar el montaje utilizado
#
# En el montaje el objeto que experimentó el movimiento parabólico fue un balín de metal,
#  experimentó dicho movimiento en varias ocasiones, entre cada una, se realizaron cambios en su
#  ángulo, estos permitieron tener una variedad de datos y analizarlos, al caer el balín sobre la mesa
#  se efectuaron mediciones gracias a la marca que este generó en el papel carbón.

# %%
print("Ahora te mostraré nuestros resultados según los datos que tomamos \n")
print("Luego lo podrás hacer tú con nuestra calculadora")
# Out:
# Ahora te mostraré nuestros resultados según los datos que tomamos
#
# Luego lo podrás hacer tú con nuestra calculadora

# %% [markdown]
# ![parabólico2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![parabólico3.PNG](data:image/png;base64,...)

# %%
print("Ahora si, prueba la cálculadora")
print("Velocidad horizontal= velocidad inicial*cos(ángulo inicial)")
print("Velocidad vertical= velocidad inicial*sin(ángulo inicial)")
print("Altura máxima=((velocidadd inicial)^2* sin (ángulo inicial)^2)/2*g")
print("Tiempo en que tarda en llegar a la altura máxima= (2*velocidad inicial*sin(ángulo inicial)/g)")
# Out:
# Ahora si, prueba la cálculadora
# Velocidad horizontal= velocidad inicial*cos(ángulo inicial)
# Velocidad vertical= velocidad inicial*sin(ángulo inicial)
# Altura máxima=((velocidadd inicial)^2* sin (ángulo inicial)^2)/2*g
# Tiempo en que tarda en llegar a la altura máxima= (2*velocidad inicial*sin(ángulo inicial)/g)

# %%
import math
vi=float(input("Digita la velocidad inicial"))
a=float(input("Digita la ángulo inicial"))


aas=math.sin(a)
ac=math.cos(a)

cuad=aas**2
cuadd=ac**2
cuaddd=vi**2

vh=(vi*ac)
vv=(vi*aas)
ah=((cuaddd*cuad)/2*9.81)
t=((2*vi*aas)/9.81)
print("La velocidad horizontal es" ,vh )
print("La velocidad vertical es ",vv )
print("La altura máxima es ",ah ) 
print("La el tiempo es ",t )
# Out:
# Digita la velocidad inicial10
# Digita la ángulo inicial30
# La velocidad horizontal es 1.5425144988758404
# La velocidad vertical es  -9.880316240928618
# La altura máxima es  478.82928344681716
# La el tiempo es  -2.0143356250618996
